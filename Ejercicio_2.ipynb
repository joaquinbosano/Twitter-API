# %%
from tweepy import API
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
import numpy as np


ACCESS_TOKEN = str(np.load("ACCESS_TOKEN.npy"))
ACCESS_TOKEN_SECRET = str(np.load("ACCESS_TOKEN_SECRET.npy"))
CONSUMER_KEY = str(np.load("CONSUMER_KEY.npy"))
CONSUMER_SECRET = str(np.load("CONSUMER_SECRET.npy"))

# %%
# # # # TWITTER AUTHENTICATER # # # #
class TwitterAuthenticator():

    def authenticate_twitter_app(self):
        auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
        auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
        return auth

# %%
# # # # TWITTER CLIENT # # # #
class TwitterClient():
    def __init__(self, twitter_user=None):
        self.auth = TwitterAuthenticator().authenticate_twitter_app()
        self.twitter_client = API(self.auth)

        self.twitter_user = twitter_user

    def get_user_timeline_tweets(self, num_tweets):
        tweets = []
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets

    def get_friend_list(self, num_friends):
        friend_list = []
        for friend in Cursor(self.twitter_client.friends, id=self.twitter_user).items(num_friends):
            friend_list.append(friend)
        return friend_list

    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets = []
        for tweet in Cursor(self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets

# %%
twitter_client = TwitterClient('pycon')
print(twitter_client.get_user_timeline_tweets(1))
# Out:
# [Status(lang='en', author=User(lang='en', followers_count=41623, profile_image_url_https='https://pbs.twimg.com/profile_images/1034096352366448641/1K7iE1ES_normal.jpg', contributors_enabled=False, name='PyCon', url='https://t.co/cDA7VmP4hV', statuses_count=3751, _api=<tweepy.api.API object at 0x0000004CB77F4550>, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme14/bg.gif', created_at=datetime.datetime(2007, 10, 16, 11, 17, 41), location='Cleveland, OH', profile_background_tile=True, profile_image_url='http://pbs.twimg.com/profile_images/1034096352366448641/1K7iE1ES_normal.jpg', _json={'lang': 'en', 'screen_name': 'pycon', 'notifications': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9475182/1535030998', 'followers_count': 41623, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1034096352366448641/1K7iE1ES_normal.jpg', 'time_zone': None, 'favourites_count': 989, 'utc_offset': None, 'protected': False, 'contributors_ena
# ...

# %%
twitter_client.get_friend_list(1)
# Out:
# [User(lang='en', muting=False, followers_count=2645, profile_image_url_https='https://pbs.twimg.com/profile_images/878792847792668672/lPROBvGJ_normal.jpg', contributors_enabled=False, name='Emily Morehouse-Valcarcel', url='https://t.co/oRQK2QNESM', statuses_count=1466, _api=<tweepy.api.API object at 0x0000004CB77F4550>, status=Status(lang='en', geo=None, retweet_count=0, truncated=True, in_reply_to_screen_name='emilyemorehouse', in_reply_to_status_id=1113840071516360704, in_reply_to_status_id_str='1113840071516360704', _api=<tweepy.api.API object at 0x0000004CB77F4550>, source_url='http://twitter.com', favorite_count=0, id=1113840863363252224, source='Twitter Web Client', _json={'lang': 'en', 'geo': None, 'retweet_count': 0, 'truncated': True, 'in_reply_to_screen_name': 'emilyemorehouse', 'in_reply_to_status_id_str': '1113840071516360704', 'created_at': 'Thu Apr 04 16:28:50 +0000 2019', 'favorited': False, 'favorite_count': 0, 'id': 1113840863363252224, 'source': '<a href="http://twi
# ...

# %%
twitter_client.get_home_timeline_tweets(6)
# Out:
# [Status(lang='en', author=User(lang='en', followers_count=89583, profile_image_url_https='https://pbs.twimg.com/profile_images/1050020823119974400/X9muqhg1_normal.jpg', contributors_enabled=False, name='Morgan Housel', url='https://t.co/eWVfAW78X9', statuses_count=12612, _api=<tweepy.api.API object at 0x0000004CB77F4550>, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme14/bg.gif', created_at=datetime.datetime(2011, 4, 19, 0, 24, 40), location='', profile_background_tile=True, profile_image_url='http://pbs.twimg.com/profile_images/1050020823119974400/X9muqhg1_normal.jpg', _json={'lang': 'en', 'screen_name': 'morganhousel', 'notifications': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/284278132/1434660086', 'followers_count': 89583, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050020823119974400/X9muqhg1_normal.jpg', 'time_zone': None, 'favourites_count': 45845, 'utc_offset': None, 'protected': False, 'contributor
# ...
